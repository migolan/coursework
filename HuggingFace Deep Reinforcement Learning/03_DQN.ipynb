# %% [markdown]
# <a href="https://colab.research.google.com/github/migolan/RL-notebooks/blob/main/HF_RL_unit3_distilled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Intro
# This notebook is based on https://huggingface.co/learn/deep-rl-course.
#
# * Train a DQN Agent using [RL-Baselines3-Zoo](https://github.com/DLR-RM/rl-baselines3-zoo), which is built over [StableBaselines3](https://github.com/DLR-RM/stable-baselines3), on the [SpaceInvadersNoFrameskip-v4](https://ale.farama.org/environments/space_invaders) gymnasium environment
# * Load and evaluate trained models from the [HF SB3 zoo](https://huggingface.co/sb3)

# %% [markdown]
# # Installations

# %%
# %%capture

# !pip install git+https://github.com/DLR-RM/rl-baselines3-zoo
# !apt-get install swig cmake ffmpeg
# !pip install gymnasium[atari]
# !pip install gymnasium[accept-rom-license]
# !apt install python-opengl
# !apt install xvfb
# !pip3 install pyvirtualdisplay

# %% [markdown]
# # Create a training hyperparameter config file for RL-Baselines3-Zoo
#
# `dqn.yml`:
#
# ```
# SpaceInvadersNoFrameskip-v4:
#   env_wrapper:
#     - stable_baselines3.common.atari_wrappers.AtariWrapper
#   frame_stack: 4
#   policy: 'CnnPolicy'
#   n_timesteps: !!float 1e6
#   buffer_size: 100000
#   learning_rate: !!float 1e-4
#   batch_size: 32
#   learning_starts: 100000
#   target_update_interval: 1000
#   train_freq: 4
#   gradient_steps: 1
#   exploration_fraction: 0.1
#   exploration_final_eps: 0.01
#   # If True, you need to deactivate handle_timeout_termination
#   # in the replay_buffer_kwargs
#   optimize_memory_usage: False
# ```
#
# - `Atari Wrapper` preprocesses the input (frame reduction ,grayscale, stack 4 frames)
# - `CnnPolicy` uses Convolutional layers to process the frames
# - Train for `n_timesteps`
# - `buffer_size` (experience replay) is the number of experience steps saved to train again the agent with
#
# This will take a long time, don't use over 1M timesteps (will take about an hour).
#
# In order to optimize hyperparamteres, focus on these 3:
# - `learning_rate`
# - `buffer_size (Experience Memory size)`
# - `batch_size`
#
# Check the documentation to understand what each hyperparameters does: https://stable-baselines3.readthedocs.io/en/master/modules/dqn.html#parameters

# %% [markdown]
# # Train a Deep Q-Learning Agent to Play Space Invaders

# %%
# !python -m rl_zoo3.train  --algo dqn  --env SpaceInvadersNoFrameskip-v4  -f logs/  -c dqn.yml
# Out:
# 2024-12-28 08:00:50.267470: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-28 08:00:50.288026: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-28 08:00:50.293833: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-28 08:00:50.309205: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-28 08:00:51.369313: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ========== SpaceInvadersNoFrameskip-v4 ==========
# Seed: 3060691216
# Loading hyperparameters from: dqn.yml
# Default hyperparameters for environment (ones being tuned will be overridden):
# OrderedDict([('batch_size', 32),
#              ('buffer_size', 100000),
#              ('env_wrapper',
#               ['stable_baselines3.common.atari_wrappers.AtariWrapper']),
#              ('exploration_final_eps', 0.01),
#              ('exploration_fraction', 0.1),
#              ('frame_stack', 4),
#              ('gradient_steps', 1),
#              ('learning_rate', 0.0001),
#              ('learning_starts', 100000),
#              ('n_timesteps', 100000.0),
#              ('optimize_memory_usage', False),
#              ('policy', 'CnnPolicy'),
#              ('target_update_interval', 1000),
#              ('train_freq', 4)])
# Using 1 environments
# Creating test environment
# A.L.E: Arcade Learning Environment (version 0.10.1+unknown)
# [Powered by Stella]
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Using cuda device
# Log path: logs//dqn/SpaceInvadersNoFrameskip-v4_1
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 130      |
# |    exploration_rate | 0.936    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 556      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 651      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.7e+03  |
# |    ep_rew_mean      | 108      |
# |    exploration_rate | 0.898    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 495      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1032     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.59e+03 |
# |    ep_rew_mean      | 93.8     |
# |    exploration_rate | 0.848    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 484      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 1540     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.67e+03 |
# |    ep_rew_mean      | 99       |
# |    exploration_rate | 0.778    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 466      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 2241     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.66e+03 |
# |    ep_rew_mean      | 98.3     |
# |    exploration_rate | 0.705    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 447      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 2983     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.86e+03 |
# |    ep_rew_mean      | 132      |
# |    exploration_rate | 0.641    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 467      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 3624     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.87e+03 |
# |    ep_rew_mean      | 130      |
# |    exploration_rate | 0.577    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 490      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 4277     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.95e+03 |
# |    ep_rew_mean      | 138      |
# |    exploration_rate | 0.504    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 512      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 5006     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.93e+03 |
# |    ep_rew_mean      | 130      |
# |    exploration_rate | 0.439    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 527      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 5663     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 163      |
# |    exploration_rate | 0.348    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 547      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 6589     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 176      |
# |    exploration_rate | 0.269    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 560      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 7384     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.212    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 567      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 7962     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 169      |
# |    exploration_rate | 0.125    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 577      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 8835     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 163      |
# |    exploration_rate | 0.0868   |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 579      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 9224     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.0292   |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 576      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 9806     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 565      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 10344    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 553      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 11035    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 558      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 11780    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 564      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 12473    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 568      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 13189    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 570      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 13580    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.98e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 574      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 14237    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.98e+03 |
# |    ep_rew_mean      | 147      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 579      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 15039    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 585      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 15845    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 591      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 16919    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 592      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 17292    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 161      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 593      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 18196    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 584      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 18940    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 577      |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 19500    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 578      |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 20161    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 580      |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 20776    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 583      |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 21481    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 586      |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 22194    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 588      |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 22713    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 591      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 23667    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 169      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 596      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 24966    |
# ----------------------------------
# Eval num_timesteps=25000, episode_reward=4.00 +/- 5.83
# Episode length: 1640.60 +/- 159.71
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 1.64e+03 |
# |    mean_reward      | 4        |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 25000    |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 167      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 511      |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 25411    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 165      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 515      |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 26145    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 517      |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 26616    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 520      |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 27317    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 161      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 522      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 27758    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 525      |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 28403    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 527      |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 29057    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 163      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 530      |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 29714    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 163      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 533      |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 30481    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 161      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 533      |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 31320    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 163      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 529      |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 32332    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 168      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 530      |
# |    time_elapsed     | 62       |
# |    total_timesteps  | 33311    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 166      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 532      |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 33848    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 165      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 534      |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 34604    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 164      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 536      |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 35214    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 163      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 538      |
# |    time_elapsed     | 66       |
# |    total_timesteps  | 35684    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 163      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 539      |
# |    time_elapsed     | 67       |
# |    total_timesteps  | 36244    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 161      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 540      |
# |    time_elapsed     | 67       |
# |    total_timesteps  | 36630    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 542      |
# |    time_elapsed     | 68       |
# |    total_timesteps  | 37076    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 543      |
# |    time_elapsed     | 69       |
# |    total_timesteps  | 37513    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 543      |
# |    time_elapsed     | 69       |
# |    total_timesteps  | 37939    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 544      |
# |    time_elapsed     | 70       |
# |    total_timesteps  | 38531    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 545      |
# |    time_elapsed     | 71       |
# |    total_timesteps  | 39073    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 542      |
# |    time_elapsed     | 73       |
# |    total_timesteps  | 40020    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 541      |
# |    time_elapsed     | 76       |
# |    total_timesteps  | 41293    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 543      |
# |    time_elapsed     | 77       |
# |    total_timesteps  | 42114    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 544      |
# |    time_elapsed     | 78       |
# |    total_timesteps  | 42601    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 546      |
# |    time_elapsed     | 79       |
# |    total_timesteps  | 43258    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 547      |
# |    time_elapsed     | 80       |
# |    total_timesteps  | 44031    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 550      |
# |    time_elapsed     | 81       |
# |    total_timesteps  | 44950    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 163      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 552      |
# |    time_elapsed     | 83       |
# |    total_timesteps  | 45959    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 167      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 555      |
# |    time_elapsed     | 85       |
# |    total_timesteps  | 47270    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 165      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 554      |
# |    time_elapsed     | 86       |
# |    total_timesteps  | 47760    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 164      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 553      |
# |    time_elapsed     | 87       |
# |    total_timesteps  | 48152    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 551      |
# |    time_elapsed     | 88       |
# |    total_timesteps  | 48683    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 166      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 550      |
# |    time_elapsed     | 90       |
# |    total_timesteps  | 49737    |
# ----------------------------------
# Eval num_timesteps=50000, episode_reward=1.00 +/- 2.00
# Episode length: 2134.60 +/- 575.40
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.13e+03 |
# |    mean_reward      | 1        |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 50000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 165      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 517      |
# |    time_elapsed     | 97       |
# |    total_timesteps  | 50369    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 168      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 519      |
# |    time_elapsed     | 98       |
# |    total_timesteps  | 51214    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 168      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 520      |
# |    time_elapsed     | 100      |
# |    total_timesteps  | 52105    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 167      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 519      |
# |    time_elapsed     | 101      |
# |    total_timesteps  | 52652    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 170      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 517      |
# |    time_elapsed     | 103      |
# |    total_timesteps  | 53495    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.16e+03 |
# |    ep_rew_mean      | 174      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 520      |
# |    time_elapsed     | 105      |
# |    total_timesteps  | 54736    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.17e+03 |
# |    ep_rew_mean      | 176      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 522      |
# |    time_elapsed     | 106      |
# |    total_timesteps  | 55645    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.17e+03 |
# |    ep_rew_mean      | 175      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 523      |
# |    time_elapsed     | 107      |
# |    total_timesteps  | 56148    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.17e+03 |
# |    ep_rew_mean      | 174      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 525      |
# |    time_elapsed     | 108      |
# |    total_timesteps  | 56886    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.16e+03 |
# |    ep_rew_mean      | 173      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 527      |
# |    time_elapsed     | 109      |
# |    total_timesteps  | 57830    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.18e+03 |
# |    ep_rew_mean      | 176      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 528      |
# |    time_elapsed     | 110      |
# |    total_timesteps  | 58594    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.19e+03 |
# |    ep_rew_mean      | 178      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 530      |
# |    time_elapsed     | 111      |
# |    total_timesteps  | 59373    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.17e+03 |
# |    ep_rew_mean      | 174      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 531      |
# |    time_elapsed     | 112      |
# |    total_timesteps  | 59808    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.16e+03 |
# |    ep_rew_mean      | 172      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 531      |
# |    time_elapsed     | 113      |
# |    total_timesteps  | 60308    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.17e+03 |
# |    ep_rew_mean      | 174      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 529      |
# |    time_elapsed     | 115      |
# |    total_timesteps  | 61396    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.17e+03 |
# |    ep_rew_mean      | 175      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 529      |
# |    time_elapsed     | 117      |
# |    total_timesteps  | 62093    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.17e+03 |
# |    ep_rew_mean      | 176      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 530      |
# |    time_elapsed     | 118      |
# |    total_timesteps  | 62679    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.18e+03 |
# |    ep_rew_mean      | 176      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 531      |
# |    time_elapsed     | 119      |
# |    total_timesteps  | 63260    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.18e+03 |
# |    ep_rew_mean      | 175      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 532      |
# |    time_elapsed     | 120      |
# |    total_timesteps  | 63916    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.17e+03 |
# |    ep_rew_mean      | 173      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 533      |
# |    time_elapsed     | 120      |
# |    total_timesteps  | 64458    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.18e+03 |
# |    ep_rew_mean      | 174      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 535      |
# |    time_elapsed     | 122      |
# |    total_timesteps  | 65814    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.18e+03 |
# |    ep_rew_mean      | 176      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 536      |
# |    time_elapsed     | 123      |
# |    total_timesteps  | 66258    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.18e+03 |
# |    ep_rew_mean      | 175      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 537      |
# |    time_elapsed     | 124      |
# |    total_timesteps  | 66825    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.19e+03 |
# |    ep_rew_mean      | 176      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 538      |
# |    time_elapsed     | 125      |
# |    total_timesteps  | 67301    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.17e+03 |
# |    ep_rew_mean      | 176      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 538      |
# |    time_elapsed     | 125      |
# |    total_timesteps  | 67654    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.15e+03 |
# |    ep_rew_mean      | 174      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 539      |
# |    time_elapsed     | 126      |
# |    total_timesteps  | 68066    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 173      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 539      |
# |    time_elapsed     | 127      |
# |    total_timesteps  | 68545    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 172      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 538      |
# |    time_elapsed     | 128      |
# |    total_timesteps  | 69163    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 170      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 536      |
# |    time_elapsed     | 130      |
# |    total_timesteps  | 70034    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 169      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 537      |
# |    time_elapsed     | 131      |
# |    total_timesteps  | 70534    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 174      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 538      |
# |    time_elapsed     | 132      |
# |    total_timesteps  | 71296    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 173      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 539      |
# |    time_elapsed     | 133      |
# |    total_timesteps  | 71834    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 176      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 540      |
# |    time_elapsed     | 134      |
# |    total_timesteps  | 72938    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 176      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 541      |
# |    time_elapsed     | 135      |
# |    total_timesteps  | 73502    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 175      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 542      |
# |    time_elapsed     | 136      |
# |    total_timesteps  | 74114    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 174      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 543      |
# |    time_elapsed     | 137      |
# |    total_timesteps  | 74692    |
# ----------------------------------
# Eval num_timesteps=75000, episode_reward=5.00 +/- 5.48
# Episode length: 2019.00 +/- 622.46
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.02e+03 |
# |    mean_reward      | 5        |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 75000    |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 176      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 517      |
# |    time_elapsed     | 145      |
# |    total_timesteps  | 75223    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 175      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 518      |
# |    time_elapsed     | 146      |
# |    total_timesteps  | 75865    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 170      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 520      |
# |    time_elapsed     | 147      |
# |    total_timesteps  | 76917    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 174      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 521      |
# |    time_elapsed     | 148      |
# |    total_timesteps  | 77608    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 173      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 522      |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 78196    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 174      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 523      |
# |    time_elapsed     | 150      |
# |    total_timesteps  | 78921    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 173      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 524      |
# |    time_elapsed     | 151      |
# |    total_timesteps  | 79381    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 174      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 525      |
# |    time_elapsed     | 152      |
# |    total_timesteps  | 80186    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 174      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 526      |
# |    time_elapsed     | 153      |
# |    total_timesteps  | 81004    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 172      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 527      |
# |    time_elapsed     | 154      |
# |    total_timesteps  | 81424    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 171      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 526      |
# |    time_elapsed     | 155      |
# |    total_timesteps  | 82073    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 171      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 526      |
# |    time_elapsed     | 156      |
# |    total_timesteps  | 82565    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 170      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 525      |
# |    time_elapsed     | 158      |
# |    total_timesteps  | 83239    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 169      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 526      |
# |    time_elapsed     | 159      |
# |    total_timesteps  | 84015    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 167      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 527      |
# |    time_elapsed     | 160      |
# |    total_timesteps  | 84450    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 167      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 527      |
# |    time_elapsed     | 161      |
# |    total_timesteps  | 84976    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 167      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 528      |
# |    time_elapsed     | 161      |
# |    total_timesteps  | 85622    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 166      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 528      |
# |    time_elapsed     | 162      |
# |    total_timesteps  | 85949    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 165      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 529      |
# |    time_elapsed     | 163      |
# |    total_timesteps  | 86280    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 165      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 530      |
# |    time_elapsed     | 164      |
# |    total_timesteps  | 86989    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 166      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 516      |
# |    fps              | 530      |
# |    time_elapsed     | 165      |
# |    total_timesteps  | 87644    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 168      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 531      |
# |    time_elapsed     | 166      |
# |    total_timesteps  | 88510    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 169      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 524      |
# |    fps              | 532      |
# |    time_elapsed     | 167      |
# |    total_timesteps  | 89212    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 169      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 528      |
# |    fps              | 533      |
# |    time_elapsed     | 168      |
# |    total_timesteps  | 89844    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 169      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 532      |
# |    fps              | 533      |
# |    time_elapsed     | 169      |
# |    total_timesteps  | 90245    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 169      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 532      |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 90890    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 170      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 531      |
# |    time_elapsed     | 172      |
# |    total_timesteps  | 91624    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 171      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 544      |
# |    fps              | 533      |
# |    time_elapsed     | 173      |
# |    total_timesteps  | 92800    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 170      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 548      |
# |    fps              | 534      |
# |    time_elapsed     | 175      |
# |    total_timesteps  | 93559    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 171      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 552      |
# |    fps              | 535      |
# |    time_elapsed     | 175      |
# |    total_timesteps  | 94046    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 169      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 556      |
# |    fps              | 535      |
# |    time_elapsed     | 176      |
# |    total_timesteps  | 94607    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 167      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 536      |
# |    time_elapsed     | 177      |
# |    total_timesteps  | 95238    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 167      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 564      |
# |    fps              | 537      |
# |    time_elapsed     | 178      |
# |    total_timesteps  | 95879    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 568      |
# |    fps              | 538      |
# |    time_elapsed     | 179      |
# |    total_timesteps  | 96545    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 572      |
# |    fps              | 538      |
# |    time_elapsed     | 180      |
# |    total_timesteps  | 97302    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 161      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 576      |
# |    fps              | 539      |
# |    time_elapsed     | 182      |
# |    total_timesteps  | 98316    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 166      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 537      |
# |    time_elapsed     | 185      |
# |    total_timesteps  | 99550    |
# ----------------------------------
# Eval num_timesteps=100000, episode_reward=6.00 +/- 7.35
# Episode length: 1659.00 +/- 185.46
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 1.66e+03 |
# |    mean_reward      | 6        |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 100000   |
# ----------------------------------
# New best mean reward!
# Saving to logs//dqn/SpaceInvadersNoFrameskip-v4_1

# %% [markdown]
# # Evaluate the agent
# RL-Baselines3-Zoo provides `enjoy.py`, a python script to evaluate the agent. In most RL libraries, evaluation scripts are called `enjoy.py`.

# %%
# !python -m rl_zoo3.enjoy  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --n-timesteps 5000  --folder logs/
# Out:
# 2024-12-28 08:04:21.972376: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-28 08:04:22.005516: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-28 08:04:22.015682: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-28 08:04:22.039978: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-28 08:04:23.389428: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Loading latest experiment, id=1
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_1/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.10.1+unknown)
# [Powered by Stella]
# Stacking 4 frames
# Atari Episode Score: 5.00
# Atari Episode Length 2061
# Atari Episode Score: 0.00
# Atari Episode Length 1511
# Atari Episode Score: 0.00
# Atari Episode Length 1511
# Atari Episode Score: 0.00
# Atari Episode Length 1511
# Atari Episode Score: 25.00
# Atari Episode Length 2753
# Atari Episode Score: 0.00
# Atari Episode Length 1511
# Atari Episode Score: 30.00
# Atari Episode Length 2827
# Atari Episode Score: 5.00
# Atari Episode Length 2061
# Atari Episode Score: 0.00
# Atari Episode Length 1511
# Atari Episode Score: 0.00
# Atari Episode Length 1511
# Atari Episode Score: 0.00
# Atari Episode Length 1511

# %% [markdown]
# # Generate replay video

# %%
# !python -m rl_zoo3.record_video  --algo dqn  --env SpaceInvadersNoFrameskip-v4  -n 1000  --load-best  -f logs/
# Out:
# 2024-12-28 08:07:46.437996: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-28 08:07:46.472235: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-28 08:07:46.482801: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-28 08:07:46.506112: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-28 08:07:47.650947: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Loading latest experiment, id=1
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_1/best_model.zip
# A.L.E: Arcade Learning Environment (version 0.10.1+unknown)
# [Powered by Stella]
# Stacking 4 frames
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_1/best_model.zip
# Wrapping the env in a VecTransposeImage.
# Saving video to /content/logs/dqn/SpaceInvadersNoFrameskip-v4_1/videos/best-model-dqn-SpaceInvadersNoFrameskip-v4-step-0-to-step-1000.mp4
# /usr/local/lib/python3.10/dist-packages/moviepy/config_defaults.py:1: DeprecationWarning: invalid escape sequence '\P'
#   """
# Moviepy - Building video /content/logs/dqn/SpaceInvadersNoFrameskip-v4_1/videos/best-model-dqn-SpaceInvadersNoFrameskip-v4-step-0-to-step-1000.mp4.
# Moviepy - Writing video /content/logs/dqn/SpaceInvadersNoFrameskip-v4_1/videos/best-model-dqn-SpaceInvadersNoFrameskip-v4-step-0-to-step-1000.mp4
#
# Moviepy - Done !
# Moviepy - video ready /content/logs/dqn/SpaceInvadersNoFrameskip-v4_1/videos/best-model-dqn-SpaceInvadersNoFrameskip-v4-step-0-to-step-1000.mp4

# %% [markdown]
# # Publish the trained model on the HF Hub

# %%
from huggingface_hub import notebook_login # To log to our Hugging Face account to be able to upload models to the Hub.
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# !python -m rl_zoo3.push_to_hub  --algo dqn  --no-render  --env SpaceInvadersNoFrameskip-v4  --repo-name dqn-SpaceInvadersNoFrameskip-v4  -orga migolan  -f logs/
# Out:
# 2024-12-28 08:10:31.592453: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-28 08:10:31.613581: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-28 08:10:31.620020: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-28 08:10:31.634898: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-28 08:10:32.693487: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Loading latest experiment, id=1
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_1/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.10.1+unknown)
# [Powered by Stella]
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Uploading to migolan/dqn-SpaceInvadersNoFrameskip-v4, make sure to have the rights
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to some
# minutes if video generation is activated. This is a work in progress: if you
# encounter a bug, please open an issue.
# Fetching 14 files:   0% 0/14 [00:00<?, ?it/s]
# config.yml: 100% 549/549 [00:00<00:00, 4.39MB/s]
#
# args.yml: 100% 1.24k/1.24k [00:00<00:00, 10.0MB/s]
#
# (…)oFrameskip-v4/_stable_baselines3_version: 100% 5.00/5.00 [00:00<00:00, 51.5kB/s]
#
# .gitattributes: 100% 1.56k/1.56k [00:00<00:00, 13.6MB/s]
# Fetching 14 files:   7% 1/14 [00:00<00:03,  4.07it/s]
# dqn-SpaceInvadersNoFrameskip-v4.zip:   0% 0.00/27.2M [00:00<?, ?B/s]
#
# policy.optimizer.pth:   0% 0.00/13.5M [00:00<?, ?B/s]
#
#
# README.md: 100% 2.80k/2.80k [00:00<00:00, 14.4MB/s]
# Fetching 14 files:  14% 2/14 [00:00<00:02,  5.11it/s]
#
#
# dqn-SpaceInvadersNoFrameskip-v4/data:   0% 0.00/207k [00:00<?, ?B/s]
#
#
#
# pytorch_variables.pth: 100% 864/864 [00:00<00:00, 7.20MB/s]
#
#
#
#
# policy.pth:   0% 0.00/13.5M [00:00<?, ?B/s]
#
#
#
#
# (…)ceInvadersNoFrameskip-v4/system_info.txt: 100% 260/260 [00:00<00:00, 1.36MB/s]
#
#
#
# dqn-SpaceInvadersNoFrameskip-v4/data: 100% 207k/207k [00:00<00:00, 1.94MB/s]
#
#
#
# env_kwargs.yml: 100% 23.0/23.0 [00:00<00:00, 216kB/s]
#
#
#
# results.json: 100% 153/153 [00:00<00:00, 878kB/s]
#
#
# policy.optimizer.pth:  78% 10.5M/13.5M [00:00<00:00, 32.9MB/s]
# policy.optimizer.pth: 100% 13.5M/13.5M [00:00<00:00, 33.0MB/s]
#
#
# train_eval_metrics.zip: 100% 37.3k/37.3k [00:00<00:00, 9.75MB/s]
#
#
#
#
# policy.pth: 100% 13.5M/13.5M [00:00<00:00, 36.9MB/s]
#
# dqn-SpaceInvadersNoFrameskip-v4.zip:  77% 21.0M/27.2M [00:00<00:00, 30.0MB/s]
# dqn-SpaceInvadersNoFrameskip-v4.zip: 100% 27.2M/27.2M [00:00<00:00, 30.6MB/s]
# Fetching 14 files: 100% 14/14 [00:01<00:00, 11.76it/s]
# Saving model to: hub/dqn-SpaceInvadersNoFrameskip-v4/dqn-SpaceInvadersNoFrameskip-v4
# ℹ Pushing repo dqn-SpaceInvadersNoFrameskip-v4 to the Hugging Face
# Hub
# policy.optimizer.pth:   0% 0.00/1.12k [00:00<?, ?B/s]
# dqn-SpaceInvadersNoFrameskip-v4.zip:   0% 0.00/13.7M [00:00<?, ?B/s]
#
# policy.pth:   0% 0.00/13.5M [00:00<?, ?B/s]
#
#
# train_eval_metrics.zip:   0% 0.00/5.70k [00:00<?, ?B/s]
#
#
#
# Upload 4 LFS files:   0% 0/4 [00:00<?, ?it/s]
# dqn-SpaceInvadersNoFrameskip-v4.zip:  65% 8.85M/13.7M [00:00<00:00, 88.5MB/s]
#
# policy.optimizer.pth: 100% 1.12k/1.12k [00:00<00:00, 5.79kB/s]
#
#
# policy.pth:  33% 4.52M/13.5M [00:00<00:00, 14.4MB/s]
#
#
#
# Upload 4 LFS files:  25% 1/4 [00:00<00:01,  2.92it/s]
#
# train_eval_metrics.zip: 100% 5.70k/5.70k [00:00<00:00, 14.0kB/s]
# dqn-SpaceInvadersNoFrameskip-v4.zip: 100% 13.7M/13.7M [00:00<00:00, 33.0MB/s]
#
#
# policy.pth: 100% 13.5M/13.5M [00:01<00:00, 10.7MB/s]
#
#
#
#
# Upload 4 LFS files: 100% 4/4 [00:01<00:00,  2.79it/s]
# ℹ Your model is pushed to the hub. You can view your model here:
# https://huggingface.co/migolan/dqn-SpaceInvadersNoFrameskip-v4

# %% [markdown]
# # Load and evaluate trained models from the HF SB3 zoo
# The Stable-Baselines3 team has uploaded more than 150 trained Deep Reinforcement Learning agents on the HF Hub.
#
# You can find them here: https://huggingface.co/sb3

# %%
# Download model and save it into the logs/ folder
# !python -m rl_zoo3.load_from_hub --algo dqn --env BeamRiderNoFrameskip-v4 -orga sb3 -f rl_trained/
# Evaluate model
# !python -m rl_zoo3.enjoy --algo dqn --env BeamRiderNoFrameskip-v4 -n 5000  -f rl_trained/ --no-render

# %% [markdown]
# # Some additional challenges
# The best way to learn **is to try things by your own**!
#
# Here's a list of environments you can try to train your agent with:
# - BeamRiderNoFrameskip-v4
# - BreakoutNoFrameskip-v4
# - EnduroNoFrameskip-v4
# - PongNoFrameskip-v4
#
# **If you want to learn to implement Deep Q-Learning by yourself**, look at CleanRL implementation: https://github.com/vwxyzjn/cleanrl/blob/master/cleanrl/dqn_atari.py
